# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\MYPC\\Downloads\\online_retail_sales.csv.csv")
df
# Out:
#      order_date product_category            product_name  \
# 0    2025-07-05      Electronics        Wireless Earbuds
# 1    2025-07-06         Clothing              Men T-Shir
# 2    2025-07-07             Home  Non-Stick Cookware Set
# 3    2025-07-08           Beauty              FAce Serum
# 4    2025-07-09           Sports                Yoga Mat
# ..          ...              ...                     ...
# 107  2025-10-20             Home  Non-Stick Cookware Set
# 108  2025-10-21           Beauty              FAce Serum
# 109  2025-10-22           Sports                Yoga Mat
# 110  2025-10-23      Electronics            Mobile Phone
# 111  2025-10-24             Home                     NaN
#
#                           price  units_sold  discount_pct payment_method  \
# 0                          2499           2            10            UPI
# 1                           799           1            10    Credit Card
# ...

# %%
df.columns
# Out:
# Index(['order_date', 'product_category', 'product_name', 'price', 'units_sold',
#        'discount_pct', 'payment_method', 'customer_rating'],
#       dtype='object')

# %%
df.head()
# Out:
#    order_date product_category            product_name price  units_sold  \
# 0  2025-07-05      Electronics        Wireless Earbuds  2499           2
# 1  2025-07-06         Clothing              Men T-Shir   799           1
# 2  2025-07-07             Home  Non-Stick Cookware Set  3499           1
# 3  2025-07-08           Beauty              FAce Serum  1299           3
# 4  2025-07-09           Sports                Yoga Mat   999           2
#
#    discount_pct payment_method  customer_rating
# 0            10            UPI              4.3
# 1            10    Credit Card              4.0
# 2            15     Debit Card              4.5
# 3             5            UPI              4.1
# 4            25            COD              3.8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_date        112 non-null    object
#  1   product_category  112 non-null    object
#  2   product_name      110 non-null    object
#  3   price             111 non-null    object
#  4   units_sold        112 non-null    int64
#  5   discount_pct      112 non-null    int64
#  6   payment_method    112 non-null    object
#  7   customer_rating   112 non-null    float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 7.1+ KB

# %%
df["price"].describe()
# Out:
# count      111
# unique       9
# top       2499
# freq        16
# Name: price, dtype: object

# %%
df["price"].unique()
# Out:
# array(['2499', '799', '3499', '1299', '999', '15000', '1400', '16000',
#        'One Thousand four Hundred ', nan], dtype=object)

# %%
df.tail()
# Out:
#      order_date product_category            product_name  \
# 107  2025-10-20             Home  Non-Stick Cookware Set
# 108  2025-10-21           Beauty              FAce Serum
# 109  2025-10-22           Sports                Yoga Mat
# 110  2025-10-23      Electronics            Mobile Phone
# 111  2025-10-24             Home                     NaN
#
#                           price  units_sold  discount_pct payment_method  \
# 107                        3499           1            15     Debit Card
# 108                        1299           3             5            UPI
# 109                         999           2            25            COD
# 110                       16000         150          1500            COD
# 111  One Thousand four Hundred          100           100    Credit Card
#
#      customer_rating
# 107              4.5
# 108              4.1
# 109              3.8
# 110              4.2
# 111              3.6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_date        112 non-null    object
#  1   product_category  112 non-null    object
#  2   product_name      110 non-null    object
#  3   price             111 non-null    object
#  4   units_sold        112 non-null    int64
#  5   discount_pct      112 non-null    int64
#  6   payment_method    112 non-null    object
#  7   customer_rating   112 non-null    float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 7.1+ KB

# %%
df["price"] = pd.to_numeric(df["price"], errors="coerce")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print("Rows before:", df.shape[0])

df = df.dropna(subset=["price"])

print("Rows after:", df.shape[0])
# Out:
# Rows before: 112
# Rows after: 107

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["revenue"] = df["price"]*df["units_sold"]*(1-df["discount_pct"]/100)
# Out:
# C:\Users\MYPC\AppData\Local\Temp\ipykernel_7192\3842144921.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["revenue"] = df["price"]*df["units_sold"]*(1-df["discount_pct"]/100)

# %%
df.head()
# Out:
#    order_date product_category            product_name   price  units_sold  \
# 0  2025-07-05      Electronics        Wireless Earbuds  2499.0           2
# 1  2025-07-06         Clothing              Men T-Shir   799.0           1
# 2  2025-07-07             Home  Non-Stick Cookware Set  3499.0           1
# 3  2025-07-08           Beauty              FAce Serum  1299.0           3
# 4  2025-07-09           Sports                Yoga Mat   999.0           2
#
#    discount_pct payment_method  customer_rating  revenue
# 0            10            UPI              4.3  4498.20
# 1            10    Credit Card              4.0   719.10
# 2            15     Debit Card              4.5  2974.15
# 3             5            UPI              4.1  3702.15
# 4            25            COD              3.8  1498.50

# %%
df.describe()
# Out:
#               price  units_sold  discount_pct  customer_rating       revenue
# count    107.000000  107.000000    107.000000       107.000000  1.070000e+02
# mean    3788.046729   34.971963    245.000000         4.151402 -4.786796e+06
# std     4914.491462   57.415641    529.452369         0.243932  1.148054e+07
# min      799.000000    1.000000      5.000000         3.600000 -3.360000e+07
# 25%      999.000000    1.000000     10.000000         4.000000  0.000000e+00
# 50%     1400.000000    2.000000     15.000000         4.200000  1.498500e+03
# 75%     3499.000000  100.000000    100.000000         4.300000  3.702150e+03
# max    16000.000000  150.000000   1500.000000         4.500000  4.498200e+03

# %%
df["revenue"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['order_date', 'product_category', 'product_name', 'price', 'units_sold',
#        'discount_pct', 'payment_method', 'customer_rating', 'revenue'],
#       dtype='object')

# %%
df["order_date"] = pd.to_datetime(df["order_date"], errors = "coerce")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 107 entries, 0 to 110
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_date        107 non-null    datetime64[ns]
#  1   product_category  107 non-null    object
#  2   product_name      107 non-null    object
#  3   price             107 non-null    float64
#  4   units_sold        107 non-null    int64
#  5   discount_pct      107 non-null    int64
#  6   payment_method    107 non-null    object
#  7   customer_rating   107 non-null    float64
#  8   revenue           107 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(3)
# memory usage: 8.4+ KB
# C:\Users\MYPC\AppData\Local\Temp\ipykernel_7192\1983347901.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df["month"] = df["order_date"].dt.month
df["month"]
# Out:
# C:\Users\MYPC\AppData\Local\Temp\ipykernel_7192\3124930006.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["month"] = df["order_date"].dt.month
# 0       7
# 1       7
# 2       7
# 3       7
# 4       7
#        ..
# 106    10
# 107    10
# 108    10
# 109    10
# 110    10
# Name: month, Length: 107, dtype: int32

# %%
monthly_revenue = df.groupby(df["order_date"].dt.to_period("M"))["revenue"].sum()
monthly_revenue.index = monthly_revenue.index.to_timestamp()

plt.plot(monthly_revenue.index, monthly_revenue.values)
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.title("Monthly Revenue Trend")
plt.xticks(rotation = 45)
plt.show()
